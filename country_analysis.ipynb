# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
country_df = pd.read_csv("countryexports.csv")
for col in country_df:
    if col != 'Partner':
        country_df[col] = pd.to_numeric(pd.Series(country_df[col]), errors = 'coerce')
country_df.head()
# Out:
#   Partner          2007          2008          2009          2010  \
# 0   World  1.148200e+12  1.287440e+12  1.056040e+12  1.278490e+12
# 1  Canada  2.488880e+11  2.611500e+11  2.046580e+11  2.492560e+11
# 2  Mexico  1.359180e+11  1.512200e+11  1.288920e+11  1.636650e+11
# 3   China  6.293689e+10  6.973284e+10  6.949668e+10  9.191108e+10
# 4   Japan  6.115958e+10  6.514175e+10  5.113418e+10  6.047185e+10
#
#            2011          2012          2013          2014          2015  \
# 0  1.482510e+12  1.545820e+12  1.578520e+12  1.621870e+12  1.503330e+12
# 1  2.812920e+11  2.926510e+11  3.007550e+11  3.128170e+11  2.808550e+11
# 2  1.982890e+11  2.158750e+11  2.259540e+11  2.410070e+11  2.364600e+11
# 3  1.041220e+11  1.105170e+11  1.217460e+11  1.236570e+11  1.158730e+11
# 4  6.579974e+10  6.997579e+10  6.523741e+10  6.689184e+10  6.238781e+10
#
#            2016          2017
# 0  1.451020e+12  1.546270e+12
# 1  2.667340e+11  2.822650e+11
# 2  2.300510e+11  2.433140e+11
# ...

# %%
exports_df = country_df.rename(columns={'Partner': 'Country', '2007': '2007 US Exports ($)', '2008': '2008 US Exports ($)', '2009': '2009 US Exports ($)',
                          '2010': '2010 US Exports ($)', '2011': '2011 US Exports ($)', '2012': '2012 US Exports ($)',
                          '2013': '2013 US Exports ($)', '2014': '2014 US Exports ($)', '2015': '2015 US Exports ($)',
                          '2016': '2016 US Exports ($)', '2017': '2017 US Exports ($)'})
exports_df.head()
# Out:
#   Country  2007 US Exports ($)  2008 US Exports ($)  2009 US Exports ($)  \
# 0   World         1.148200e+12         1.287440e+12         1.056040e+12
# 1  Canada         2.488880e+11         2.611500e+11         2.046580e+11
# 2  Mexico         1.359180e+11         1.512200e+11         1.288920e+11
# 3   China         6.293689e+10         6.973284e+10         6.949668e+10
# 4   Japan         6.115958e+10         6.514175e+10         5.113418e+10
#
#    2010 US Exports ($)  2011 US Exports ($)  2012 US Exports ($)  \
# 0         1.278490e+12         1.482510e+12         1.545820e+12
# 1         2.492560e+11         2.812920e+11         2.926510e+11
# 2         1.636650e+11         1.982890e+11         2.158750e+11
# 3         9.191108e+10         1.041220e+11         1.105170e+11
# 4         6.047185e+10         6.579974e+10         6.997579e+10
#
#    2013 US Exports ($)  2014 US Exports ($)  2015 US Exports ($)  \
# 0         1.578520e+12         1.621870e+12         1.503330e+12
# ...

# %%
dollarchange = exports_df.copy()
dollarchange['10 Year Change ($)'] = dollarchange['2017 US Exports ($)'] - dollarchange['2007 US Exports ($)']
sorted_df = dollarchange.sort_values(by=['10 Year Change ($)'], ascending = False)
new_df = sorted_df[sorted_df.Country != 'World']
filtered_df = new_df.dropna()
filtered_df.head()
plot_df = pd.concat([filtered_df.head(5), filtered_df.tail(5)])
plot_df

#sorted_df.to_csv('test.csv', index=False)
#Graph Top 5 Changed using line graph
# Out:
#         Country  2007 US Exports ($)  2008 US Exports ($)  \
# 2        Mexico         1.359180e+11         1.512200e+11
# 3         China         6.293689e+10         6.973284e+10
# 1        Canada         2.488880e+11         2.611500e+11
# 9     Hong Kong         1.990165e+10         2.149862e+10
# 7   South Korea         3.440171e+10         3.466867e+10
# 77       Greece         2.110206e+09         1.931571e+09
# 47        Egypt         5.259281e+09         6.002196e+09
# 72     Portugal         2.478481e+09         2.645976e+09
# 67      Finland         3.133422e+09         3.760847e+09
# 46    Venezuela         1.020051e+10         1.261004e+10
#
#     2009 US Exports ($)  2010 US Exports ($)  2011 US Exports ($)  \
# 2          1.288920e+11         1.636650e+11         1.982890e+11
# 3          6.949668e+10         9.191108e+10         1.041220e+11
# 1          2.046580e+11         2.492560e+11         2.812920e+11
# ...

# %%
plot_df_transposed = plot_df.T
plot_index = plot_df_transposed.reset_index()
plot_index.columns = plot_index.iloc[0]
plot_index
line_plot = plot_index.iloc[1:]
x = line_plot[line_plot.Country != '10 Year Change ($)']
x
#df.columns = df.iloc[1]
# Out:
# 0               Country       Mexico        China       Canada    Hong Kong  \
# 1   2007 US Exports ($)  1.35918e+11  6.29369e+10  2.48888e+11  1.99017e+10
# 2   2008 US Exports ($)   1.5122e+11  6.97328e+10   2.6115e+11  2.14986e+10
# 3   2009 US Exports ($)  1.28892e+11  6.94967e+10  2.04658e+11  2.10505e+10
# 4   2010 US Exports ($)  1.63665e+11  9.19111e+10  2.49256e+11  2.65705e+10
# 5   2011 US Exports ($)  1.98289e+11  1.04122e+11  2.81292e+11  3.63988e+10
# 6   2012 US Exports ($)  2.15875e+11  1.10517e+11  2.92651e+11  3.74718e+10
# 7   2013 US Exports ($)  2.25954e+11  1.21746e+11  3.00755e+11  4.23322e+10
# 8   2014 US Exports ($)  2.41007e+11  1.23657e+11  3.12817e+11  4.09134e+10
# 9   2015 US Exports ($)   2.3646e+11  1.15873e+11  2.80855e+11  3.71827e+10
# 10  2016 US Exports ($)  2.30051e+11  1.15546e+11  2.66734e+11  3.48952e+10
# 11  2017 US Exports ($)  2.43314e+11  1.29894e+11  2.82265e+11  3.99391e+10
#
# ...

# %%
x.plot(x = 'Country', y=['Mexico', 'China', 'Canada', 'Hong Kong', 'South Korea', 'Greece', 'Egypt', 'Portugal', 'Finland', 'Venezuela'], figsize = (20,10))
#plt.xticks('2007', '2008', '2009', '2010', '2011', '2012')
#, '2013', '2014', '2015', '2016', '2017'
#plt.plot(years, wins_over_time, color="green", label="Wins")

# %%
gdp_df=pd.read_csv("countrygdp.csv")
gdp_df_transposed = gdp_df.T
reset_index = gdp_df_transposed.reset_index()
reset_index.columns = reset_index.iloc[0]
reset_index
gdp_avg = reset_index.iloc[2:]
gdp_avg.mean()
# Out:
# 0
# Country Name    1.824728e+42
# Canada          1.636545e+12
# China           8.188825e+12
# Egypt           2.465139e+11
# Finland         2.576748e+11
# Greece          2.637457e+11
# Hong Kong       2.657795e+11
# South Korea     1.235622e+12
# Mexico          1.135218e+12
# Portugal        2.293970e+11
# Venezuela       3.525536e+11
# dtype: float64

# %%
gdp_avg_df = pd.DataFrame(gdp_avg.mean().to_dict(),index=[gdp_avg.index[0]])
gdp_avg_df
# Out:
#    Country Name        Canada         China         Egypt       Finland  \
# 2  1.824728e+42  1.636545e+12  8.188825e+12  2.465139e+11  2.576748e+11
#
#          Greece     Hong Kong   South Korea        Mexico      Portugal  \
# 2  2.637457e+11  2.657795e+11  1.235622e+12  1.135218e+12  2.293970e+11
#
#       Venezuela
# 2  3.525536e+11

# %%
export_avg_df = plot_df.T
yo = export_avg_df.reset_index()
yo.columns = yo.iloc[0]


for col in yo:
    if col != 'Country':
        yo[col] = pd.to_numeric(pd.Series(yo[col]), errors = 'coerce')

y = yo.iloc[1:]
test = y[y.Country != '10 Year Change ($)']
new = pd.DataFrame(test.mean().to_dict(),index=[test.index[0]])
new
#export average^
# Out:
#          Mexico         China        Canada     Hong Kong   South Korea  \
# 1  1.973314e+11  1.014030e+11  2.710292e+11  3.255950e+10  4.024259e+10
#
#          Greece         Egypt      Portugal       Finland     Venezuela
# 1  1.228701e+09  5.360667e+09  1.340679e+09  2.329838e+09  1.043067e+10

# %%
yo
# Out:
# 0               Country       Mexico        China       Canada    Hong Kong  \
# 0               Country       Mexico        China       Canada    Hong Kong
# 1   2007 US Exports ($)  1.35918e+11  6.29369e+10  2.48888e+11  1.99017e+10
# 2   2008 US Exports ($)   1.5122e+11  6.97328e+10   2.6115e+11  2.14986e+10
# 3   2009 US Exports ($)  1.28892e+11  6.94967e+10  2.04658e+11  2.10505e+10
# 4   2010 US Exports ($)  1.63665e+11  9.19111e+10  2.49256e+11  2.65705e+10
# 5   2011 US Exports ($)  1.98289e+11  1.04122e+11  2.81292e+11  3.63988e+10
# 6   2012 US Exports ($)  2.15875e+11  1.10517e+11  2.92651e+11  3.74718e+10
# 7   2013 US Exports ($)  2.25954e+11  1.21746e+11  3.00755e+11  4.23322e+10
# 8   2014 US Exports ($)  2.41007e+11  1.23657e+11  3.12817e+11  4.09134e+10
# 9   2015 US Exports ($)   2.3646e+11  1.15873e+11  2.80855e+11  3.71827e+10
# 10  2016 US Exports ($)  2.30051e+11  1.15546e+11  2.66734e+11  3.48952e+10
# ...
