# %%
import pandas as pd
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
graph_df = pd.read_csv("DistancePlot.csv")
#plt.scatter(graph_df["Average Air Miles from US"], graph_df["Per Capita Exports"], marker="o", color="red")
graph_df["Per Capita Exports"] = graph_df["Per Capita Exports"].astype('int64')
graph_df["Average Air Miles from US"] = graph_df["Average Air Miles from US"].astype('int64')
graph_df = graph_df.rename(columns={"Population Mean": "Avg. Export Value"})
graph_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Country Name         2007          2017  \
# 0           3             3           China  62936891576  129893586716
# 1           4             4           Japan  61159582766   67605076964
# 2           5             5  United Kingdom  49981491297   56257922547
# 3           6             6         Germany  49419703142   53896753486
# 4           7             7     South Korea  34401709969   48326408702
#
#    Avg. Export Value Country Code  Population  Average Air Miles from US  \
# 0       1.014029e+11          CHN  1378665000                       7252
# 1       6.354828e+10          JPN   126994511                       6321
# 2       5.248949e+10          GBR    65637239                       4255
# 3       4.941579e+10          DEU    82667685                       4898
# 4       4.024259e+10          KOR    51250000                       6690
#
#    Per Capita Exports
# 0                  73
# 1                 500
# 2                 799
# 3                 597
# 4                 785

# %%
graph_df.plot(kind="scatter", x="Population", y="Avg. Export Value", grid=True, figsize=(15,7), s = 100,
                 
              marker="o", color="gold", alpha=.85, edgecolors="black")

plt.title("Population vs. Avg. Export Value for 100 Largest Overseas Export Market Countries", fontsize=18)
plt.savefig("MikeM_PopV_Exp.png")

# %%
graph_df.plot(kind="scatter", x="Average Air Miles from US", y="Per Capita Exports", grid=True, figsize=(15,7), s = 100,
                 
              marker="o", color="gold", alpha=.85, edgecolors="black")

plt.title("Distance vs. Per Capita Exports for 100 Largest Overseas Export Market Countries", fontsize=18)
plt.savefig("MikeM_DisV_Exp.png")

# %%
from statistics import median
arr = np.array(graph_df["Per Capita Exports"])
mid = median(arr)
# Use numpy to create quartiles
q1 = np.percentile(arr, 25)
q3 = np.percentile(arr,75)
# Print the quartiles
print(f"Q1 is {q1}")
print(f"Q3 is {q3}")
# Calculate the interquartile range
iqr = (q3 - q1)
print("interquartile range:", iqr)
# Find lower boundary
# Q1 - 1.5 * IQR
lower_boundary = q1 - (1.5 * iqr)
lower_boundary
# Find upper boundary
# Q3 + 1.5 * IQR
upper_boundary = q3 + (1.5 * iqr)
upper_boundary
# Check for any lower outliers
arr[arr <= lower_boundary]
# Check for any upper outliers
arr[arr >= upper_boundary]
# Out:
# Q1 is 75.25
# Q3 is 1103.25
# interquartile range: 1028.0
# array([ 4431,  5064,  7468, 12842,  7765, 11540, 10111,  2667, 10698],
#       dtype=int64)

# %%
# Create box plot
plt.boxplot(arr, showmeans=True)
plt.grid()
plt.title("Distance vs. Per Capita Exports Quartiles, Outliers", fontsize=12)
plt.savefig("MikeM_Box.png")
plt.show()

# %%
pop_one = graph_df.loc[graph_df["Average Air Miles from US"] < 3300, :]
# usa_ufo_df = clean_ufo_df.loc[clean_ufo_df["country"] == "us", :]
# usa_ufo_df.head()
len(pop_one)
stats.ttest_1samp(pop_one["Per Capita Exports"], graph_df["Per Capita Exports"].mean())
# Out:
# Ttest_1sampResult(statistic=2.114488270630928, pvalue=0.04660353236767158)

# %%
plt.figure(figsize=(6, 4), dpi=150)
plt.subplot(2, 1, 1)
plt.scatter(pop_one["Average Air Miles from US"], pop_one["Per Capita Exports"], label="Less than 3300 Miles")
plt.scatter(graph_df["Average Air Miles from US"], graph_df["Per Capita Exports"], label="Top 100 Countries")
plt.suptitle('Comparison of Near Group vs. All Countries', fontsize=16)


plt.subplot(2, 1, 2)            
plt.hist(pop_one["Per Capita Exports"], 10, density=True, alpha=0.7, label="Less than 3300 Miles")
plt.hist(graph_df["Per Capita Exports"], 10, density=True, alpha=0.7, label="Top 100 Countries")
plt.axvline(pop_one["Per Capita Exports"].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(graph_df["Per Capita Exports"].mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
#plt.title("Comparison of Near Group vs. All Countries", fontsize=16)
plt.savefig("MikeM_Dis_His.png")
