# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import requests

# %%
merch_expo_wld_df = pd.read_csv('DATA_HS_Total_All_Merchandise_Exports_to_World.csv')
gdp_df = pd.read_csv('gdp_csv.csv')
gdp_df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
# afg_df = gdp_df[gdp_df['Country Name']=='Albania']
# afg_df['Value'].mean()
merch_expo_wld_df.head()
# Out:
#                                                 Item           2007  \
# 0                                              TOTAL  1148198722191
# 1  84--NUCLEAR REACTORS; BOILERS; MACHINERY ETC.;...   179294453398
# 2  85--ELECTRIC MACHINERY ETC; SOUND EQUIP; TV EQ...   147811354753
# 3  27--MINERAL FUEL; OIL ETC.; BITUMIN SUBST; MIN...    42247963045
# 4        88--AIRCRAFT; SPACECRAFT; AND PARTS THEREOF    83882874225
#
#             2008           2009           2010           2011           2012  \
# 0  1287441996730  1056042963028  1278494525839  1482507755226  1545820839892
# 1   190627440227   153159958043   182902860899   205826159717   215180487807
# 2   152466732455   124817076765   151776704354   159468543383   162434694242
# 3    76940267425    55059238358    81692031854   130566667652   137332528657
# 4    84376185197    82977746555    79617922992    87757246448   104440079691
#
#             2013           2014           2015           2016           2017
# ...

# %%
merch_expo_wld_df['mean'] = merch_expo_wld_df.loc[:, '2007':'2017'].mean(axis=1)
merch_expo_wld_df_sortedby_mean = merch_expo_wld_df.sort_values(by=['mean'],ascending = False)
merch_expo_wld_df_sortedby_mean.head(15)
# Out:
#                                                  Item           2007  \
# 0                                               TOTAL  1148198722191
# 1   84--NUCLEAR REACTORS; BOILERS; MACHINERY ETC.;...   179294453398
# 2   85--ELECTRIC MACHINERY ETC; SOUND EQUIP; TV EQ...   147811354753
# 5   87--VEHICLES; EXCEPT RAILWAY OR TRAMWAY; AND P...   107212566719
# 3   27--MINERAL FUEL; OIL ETC.; BITUMIN SUBST; MIN...    42247963045
# 4         88--AIRCRAFT; SPACECRAFT; AND PARTS THEREOF    83882874225
# 6   90--OPTIC; PHOTO ETC; MEDIC OR SURGICAL INSTRM...    65216983434
# 8   71--NAT ETC PEARLS; PREC ETC STONES; PR MET ET...    40558008822
# 7                   39--PLASTICS AND ARTICLES THEREOF    48003056210
# 9                         30--PHARMACEUTICAL PRODUCTS    29242542860
# 11                              29--ORGANIC CHEMICALS    37936666628
# 10       98--SPECIAL CLASSIFICATION PROVISIONS; NESOI    31374368135
# 12                38--MISCELLANEOUS CHEMICAL PRODUCTS    18155225951
# ...

# %%
gpbycountry_gdp

# %%
#gdp_df[gdp_df['Country Name']=='China']
gpbycountry_gdp = gdp_df.groupby(['Country Name','Year'], as_index=False)

# %%
ls = gpbycountry_gdp.mean().groupby('Country Name')['Value'].mean()

# %%
ls_sorted=ls.sort_values(ascending=False)
ls_sorted.head(40)
# Out:
# Country Name
# World                                                   2.609594e+13
# High income                                             1.950705e+13
# OECD members                                            1.926956e+13
# Post-demographic dividend                               1.852443e+13
# Europe & Central Asia                                   8.631478e+12
# North America                                           7.392049e+12
# European Union                                          7.251568e+12
# IDA & IBRD total                                        6.816739e+12
# United States                                           6.773384e+12
# Low & middle income                                     6.606986e+12
# Middle income                                           6.493593e+12
# IBRD only                                               6.324996e+12
# East Asia & Pacific                                     6.267936e+12
# ...

# %%
list_of_top_countries = ['United States','Japan','Germany','China','France','United Kingdom','Italy','Russian Federation','Brazil']

# %%
df = pd.read_csv("2011_us_ag_exports.csv")
df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton
# 0          14.33  34.9   70.0   317.61
# ...

# %%
import plotly
plotly.tools.set_credentials_file(username='8135tao', api_key='wyGWY4LmNGNohXtJ3vmo')

# %%
import plotly.plotly as py


for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] + '<br>' +\
    'Beef '+df['beef']+' Dairy '+df['dairy']+'<br>'+\
    'Fruits '+df['total fruits']+' Veggies ' + df['total veggies']+'<br>'+\
    'Wheat '+df['wheat']+' Corn '+df['corn']

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = df['total exports'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Millions USD"
        )
    ) ]

layout = dict(
        title = '2011 US Agriculture Exports by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = dict(data=data, layout=layout)

#url = py.plot(fig, filename='d3-cloropleth-map')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~8135tao/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'

# %%
py.iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~8135tao/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~8135tao/0.embed" height="525px" width="100%"></iframe>

# %%
df.head()
# Out:
#   code        state category total exports   beef  pork poultry   dairy  \
# 0   AL      Alabama    state       1390.63   34.4  10.6   481.0    4.06
# 1   AK       Alaska    state         13.31    0.2   0.1     0.0    0.19
# 2   AZ      Arizona    state       1463.17   71.3  17.9     0.0  105.48
# 3   AR     Arkansas    state       3586.02   53.2  29.4   562.9    3.53
# 4   CA   California    state      16472.88  228.7  11.1   225.4  929.95
#
#   fruits fresh fruits proc total fruits veggies fresh veggies proc  \
# 0          8.0        17.1        25.11           5.5          8.9
# 1          0.0         0.0          0.0           0.6          1.0
# 2         19.3        41.0        60.27         147.5        239.4
# 3          2.2         4.7         6.88           4.4          7.1
# 4       2791.8      5944.6       8736.4         803.2       1303.5
#
#   total veggies  corn  wheat   cotton  \
# 0         14.33  34.9   70.0   317.61
# 1          1.56   0.0    0.0      0.0
# ...

# %%
data[0].keys()
# Out:
# dict_keys(['type', 'colorscale', 'autocolorscale', 'locations', 'z', 'locationmode', 'text', 'marker', 'colorbar'])
